# %%
print("Hello")
# Out:
# Hello

# %%
# 매직커맨드 : 
# "%명령어"
# IPython이 제공하는 특수 기능 명령
# %run ./4-1-1.py
# Out:
# Grade is B

# %%
# %pwd
# Out:
# 'D:\\data-science'

# %%
import os
os.chdir('D:\\data-science\\')

# %%
import os

# %%
os.chdir('C:\\Users\\yhkim\\student')

# %%
# %pwd
# Out:
# 'D:\\data-science'

# %%
# 쉘 명령어  
# "!명령어"
# python 코드가 아니라 터미널 명령어를 실행하는 기능
# !cd ..

# %%
# %pwd
# Out:
# 'D:\\data-science'
