# %%
print("Hello")
# Out:
# Hello

# %%
# %run ./4-1-1.py
# Out:
# Input Score:  20
# Grade is F

# %%
# %pwd
# Out:
# 'C:\\Users\\yhkim\\student\\1day'

# %%
os.chdir('C:\\Users\\yhkim\\student\\1day')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 os.chdir('C:\\Users\\yhkim\\student\\1day')
#
# NameError: name 'os' is not defined

# %%
import os

# %%
os.chdir('C:\\Users\\yhkim\\student')

# %%
# %pwd
# Out:
# 'C:\\Users\\yhkim\\student'

# %%
# !cd ..

# %%
# %pwd
# Out:
# 'C:\\Users\\yhkim\\student'
