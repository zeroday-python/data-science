# %%
dir(__builtins__)
# Out:
# ['ArithmeticError',
#  'AssertionError',
#  'AttributeError',
#  'BaseException',
#  'BaseExceptionGroup',
#  'BlockingIOError',
#  'BrokenPipeError',
#  'BufferError',
#  'BytesWarning',
#  'ChildProcessError',
#  'ConnectionAbortedError',
#  'ConnectionError',
#  'ConnectionRefusedError',
#  'ConnectionResetError',
#  'DeprecationWarning',
#  'EOFError',
#  'Ellipsis',
#  'EncodingWarning',
#  'EnvironmentError',
#  'Exception',
#  'ExceptionGroup',
#  'False',
#  'FileExistsError',
#  'FileNotFoundError',
#  'FloatingPointError',
#  'FutureWarning',
#  'GeneratorExit',
#  'IOError',
#  'ImportError',
#  'ImportWarning',
#  'IndentationError',
#  'IndexError',
#  'InterruptedError',
#  'IsADirectoryError',
#  'KeyError',
#  'KeyboardInterrupt',
#  'LookupError',
#  'MemoryError',
#  'ModuleNotFoundError',
#  'NameError',
#  'None',
#  'NotADirectoryError',
#  'NotImplemented',
#  'NotImplementedError',
#  'OSError',
#  'OverflowError',
#  'PendingDeprecationWarning',
# ...

# %%
import os
os.chdir?
# Out:
# Signature: os.chdir(path)
# Docstring:
# Change the current working directory to the specified path.
#
# path may always be specified as a string.
# On some platforms, path may also be specified as an open file descriptor.
#   If this functionality is unavailable, using it raises an exception.
# Type:      builtin_function_or_method

# %%
import types
dir(types)
# Out:
# ['AsyncGeneratorType',
#  'BuiltinFunctionType',
#  'BuiltinMethodType',
#  'CellType',
#  'ClassMethodDescriptorType',
#  'CodeType',
#  'CoroutineType',
#  'DynamicClassAttribute',
#  'EllipsisType',
#  'FrameType',
#  'FunctionType',
#  'GeneratorType',
#  'GenericAlias',
#  'GetSetDescriptorType',
#  'LambdaType',
#  'MappingProxyType',
#  'MemberDescriptorType',
#  'MethodDescriptorType',
#  'MethodType',
#  'MethodWrapperType',
#  'ModuleType',
#  'NoneType',
#  'NotImplementedType',
#  'SimpleNamespace',
#  'TracebackType',
#  'UnionType',
#  'WrapperDescriptorType',
#  '_GeneratorWrapper',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_calculate_meta',
#  'coroutine',
#  'get_original_bases',
#  'new_class',
#  'prepare_class',
#  'resolve_bases']

# %%
s = "pandas"

# %%
type(s)
# Out:
# str

# %%
#s.title?

# %%
s.title()
# Out:
# 'Pandas'

# %%
s[1:3]
# Out:
# 'an'

# %%
s[:2]
# Out:
# 'pa'

# %%
s[-3:]
# Out:
# 'das'

# %%
s[::2]
# Out:
# 'pna'

# %%
s[0]
# Out:
# 'p'

# %% [markdown]
# - 리스트

# %%
colors = ['gold','silver','blue','pink']

# %%
colors
# Out:
# ['gold', 'silver', 'blue', 'pink']

# %%
type(colors)
# Out:
# list

# %%
colors.append('red')

# %%
colors
# Out:
# ['gold', 'silver', 'blue', 'pink', 'red']

# %%
colors.insert(0,'red')

# %%
colors
# Out:
# ['red', 'gold', 'silver', 'blue', 'pink', 'red']

# %%
colors += 're'

# %%
colors
# Out:
# ['red', 'gold', 'silver', 'blue', 'pink', 'red', 'r', 'e']

# %%
type(colors)
# Out:
# list

# %%
colors.count('red')
# Out:
# 2

# %%
len(colors)
# Out:
# 8

# %%
colors.reverse()

# %%
colors
# Out:
# ['e', 'r', 'red', 'pink', 'blue', 'silver', 'gold', 'red']

# %%
colors.append('green')

# %%
colors
# Out:
# ['e', 'r', 'red', 'pink', 'blue', 'silver', 'gold', 'red', 'green']

# %%
colors.sort()

# %%
colors
# Out:
# ['blue', 'e', 'gold', 'green', 'pink', 'r', 'red', 'red', 'silver']

# %%
colors.sort(reverse=True)

# %%
colors
# Out:
# ['silver', 'red', 'red', 'r', 'pink', 'green', 'gold', 'e', 'blue']

# %% [markdown]
# - 세트

# %%
a = {1,2,3,4,5,5}

# %%
a
# Out:
# {1, 2, 3, 4, 5}

# %%
b = {4,5,6,7,6,7}

# %%
b
# Out:
# {4, 5, 6, 7}

# %%
a.intersection(b)
# Out:
# {4, 5}

# %%
a.union(b)
# Out:
# {1, 2, 3, 4, 5, 6, 7}

# %% [markdown]
# - 딕셔너리

# %%
d = {'sunny':1000000, 'psy':999999}

# %%
type(d)
# Out:
# dict

# %%
d2 = dict(name='psy', salary=10000000, id='sunny')

# %%
type(d2)
# Out:
# dict

# %%
for i in d2.keys():
    print(i)
# Out:
# name
# salary
# id

# %%
for i in d2.values():
    print(i)
# Out:
# psy
# 10000000
# sunny

# %%
for k,v in d2.items():
    print(k,v)
# Out:
# name psy
# salary 10000000
# id sunny

# %%
d2['name']
# Out:
# 'psy'

# %%
d2['id']
# Out:
# 'sunny'

# %%
del d2['id']

# %%
d2
# Out:
# {'name': 'psy', 'salary': 10000000}

# %%
d2.clear()

# %%
d2
# Out:
# {}

# %%
del d2

# %%
# %who
# Out:
# a	 b	 colors	 d	 i	 k	 os	 s	 types
# v
