# %%
# %pwd
# Out:
# 'C:\\Users\\student\\bigdata'

# %%
# !mkdir test1

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 1A2A-9520
#
#  C:\Users\student\bigdata 디렉터리
#
# 2020-02-04  오전 11:08    <DIR>          .
# 2020-02-04  오전 11:08    <DIR>          ..
# 2020-02-04  오전 11:07    <DIR>          .ipynb_checkpoints
# 2020-02-04  오전 11:08    <DIR>          test1
# 2020-02-03  오후 04:24            18,913 데이터타입.ipynb
# 2020-02-04  오전 10:29             6,893 모듈테스트.ipynb
# 2020-02-04  오전 11:07                72 입출력테스트.ipynb
# 2020-02-03  오후 02:38            30,810 파이썬기본.ipynb
#                4개 파일              56,688 바이트
#                4개 디렉터리  184,314,093,568 바이트 남음

# %%
# !mkdir c:\test1

# %%
# !mkdir c:/test2
# Out:
# 명령 구문이 올바르지 않습니다.

# %%
# !mkdir c:\\test3

# %%
import os

# %%
os.mkdir('c:/test4')

# %%
os.mkdir('c:\\test5')

# %%
# !dir
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 1A2A-9520
#
#  C:\Users\student\bigdata 디렉터리
#
# 2020-02-04  오전 11:13    <DIR>          .
# 2020-02-04  오전 11:13    <DIR>          ..
# 2020-02-04  오전 11:07    <DIR>          .ipynb_checkpoints
# 2020-02-04  오전 11:08    <DIR>          test1
# 2020-02-03  오후 04:24            18,913 데이터타입.ipynb
# 2020-02-04  오전 10:29             6,893 모듈테스트.ipynb
# 2020-02-04  오전 11:13             5,576 입출력테스트.ipynb
# 2020-02-03  오후 02:38            30,810 파이썬기본.ipynb
#                4개 파일              62,192 바이트
#                4개 디렉터리  184,313,745,408 바이트 남음

# %%
f = open('test1/test1.txt','w')

# %%
print('file test...',file=f)

# %%
f.close()
