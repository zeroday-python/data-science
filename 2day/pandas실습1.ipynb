# %%
import pandas as pd

# %%
sr1 = pd.Series([10, -1, 9, 7, -8])

# %%
#pd.Series?

# %%
sr1
# Out:
# 0    10
# 1    -1
# 2     9
# 3     7
# 4    -8
# dtype: int64

# %%
type(sr1)
# Out:
# pandas.core.series.Series

# %%
sr1.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
sr1.values
# Out:
# array([10, -1,  9,  7, -8])

# %%
sr1.dtype
# Out:
# dtype('int64')

# %%
sr2 = pd.Series([10, -1, 9, 7, -8], index=['a','b','c','d','e'])
sr2
# Out:
# a    10
# b    -1
# c     9
# d     7
# e    -8
# dtype: int64

# %%
sd = {'sunyoung':999999, 'kildong':100000, 'jungsun' : 9990000, 'jungjae':888999}

# %%
type(sd)
# Out:
# dict

# %%
sr3 = pd.Series(sd)

# %%
sr3
# Out:
# sunyoung     999999
# kildong      100000
# jungsun     9990000
# jungjae      888999
# dtype: int64

# %%
data = { 'names' : ['sunyoung', 'sunyoung', 'sunyoung', 'jungjae','jungjae'] ,
       'year' : [2016, 2017, 2018, 2019, 2016],
       'points' : [1.5, 1.7, 3.6, 2.4, 5.7]}

# %%
df = pd.DataFrame(data)
df
# Out:
#       names  year  points
# 0  sunyoung  2016     1.5
# 1  sunyoung  2017     1.7
# 2  sunyoung  2018     3.6
# 3   jungjae  2019     2.4
# 4   jungjae  2016     5.7

# %%
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
df.columns
# Out:
# Index(['names', 'year', 'points'], dtype='object')

# %%
df.values
# Out:
# array([['sunyoung', 2016, 1.5],
#        ['sunyoung', 2017, 1.7],
#        ['sunyoung', 2018, 3.6],
#        ['jungjae', 2019, 2.4],
#        ['jungjae', 2016, 5.7]], dtype=object)

# %%
df
# Out:
#       names  year  points
# 0  sunyoung  2016     1.5
# 1  sunyoung  2017     1.7
# 2  sunyoung  2018     3.6
# 3   jungjae  2019     2.4
# 4   jungjae  2016     5.7

# %%
df2 = pd.DataFrame(data, columns=['year', 'names', 'points', 'penalty'],
                  index=['one','two','three','four','five'])
df2
# Out:
#        year     names  points penalty
# one    2016  sunyoung     1.5     NaN
# two    2017  sunyoung     1.7     NaN
# three  2018  sunyoung     3.6     NaN
# four   2019   jungjae     2.4     NaN
# five   2016   jungjae     5.7     NaN
