# %%
import calendar

# %%
dir(calendar)

# %%
#calendar.prmonth?

# %%
help(calendar.prmonth)

# %%
calendar.prmonth(2026,5)

# %%
from datetime import date
dir(date)

# %%
# import datetime
# dir(datetime)

# %%
t = date.today()
t

# %%
def myFunc():
    b = 10
    print("test" + str(b))

# %%
a = myFunc

# %%
type(a)

# %%
type(myFunc)

# %%
a()

# %%
myFunc()

# %%
a.__doc__ = "test function by sunny...."

# %%
a?

# %%
myFunc?

# %%
myFunc = None

# %%
type(myFunc)

# %%
#myFunc()
#TypeError: 'NoneType' object is not callable

# %%
a()
