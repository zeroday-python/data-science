# %%
# %pwd

# %%
# 쥬피트 노트북 셀 인코딩(UTF-8) 변경
# Windows 콘솔의 문자 인코딩을 UTF-8로 변경하는 명령
# !chcp 65001

# %%
# !mkdir test1 #! 콘솔명령어 실행시 사용 현재폴더에 test1폴더 생성
import os
print(os.getcwd())

# %%
# !dir

# %%
# !mkdir c:\test1

# %%
# !mkdir c:/test2

# %%
# !mkdir c:\\test3

# %%
import os

# %%
os.mkdir('c:/test4')

# %%
os.mkdir('c:\\test5')

# %%
# !dir

# %%
open?

# %%
f = open('test1/test1.txt','w',encoding="UTF-8")

# %%
print('한글테스트',file=f)

# %%
f.close()
