# %%
# %pwd
# Out:
# 'C:\\Users\\yhkim\\student\\2day'

# %%
# !mkdir test1
import os
print(os.getcwd())
# Out:
# C:\Users\yhkim\student\2day
# 하위 디렉터리 또는 파일 test1이(가) 이미 있습니다.

# %%
# !dir
# Out:
#  C 드라이브의 볼륨: OS
#  볼륨 일련 번호: D61A-72B4
#
#  C:\Users\yhkim\student\2day 디렉터리
#
# 2026-04-05  오전 05:57    <DIR>          .
# 2026-03-30  오후 06:52    <DIR>          ..
# 2026-03-30  오전 11:11    <DIR>          .ipynb_checkpoints
# 2026-03-30  오후 04:23            20,903 numpy실습1.ipynb
# 2026-03-30  오후 04:23            13,018 numpy실습2.ipynb
# 2026-03-30  오후 12:42            12,601 pandas실습1.ipynb
# 2026-04-05  오전 05:46    <DIR>          test1
# 2026-04-05  오전 05:57             7,986 모듈테스트.ipynb
# 2026-04-05  오전 05:49             5,739 입출력테스트.ipynb
#                5개 파일              60,247 바이트
#                4개 디렉터리  23,531,147,264 바이트 남음

# %%
# !mkdir c:\test1

# %%
# !mkdir c:/test2
# Out:
# 명령 구문이 올바르지 않습니다.

# %%
# !mkdir c:\\test3

# %%
import os

# %%
os.mkdir('c:/test4')

# %%
os.mkdir('c:\\test5')

# %%
# !dir
# Out:
#  C 드라이브의 볼륨: OS
#  볼륨 일련 번호: D61A-72B4
#
#  C:\Users\yhkim\student\2day 디렉터리
#
# 2026-04-05  오전 05:57    <DIR>          .
# 2026-03-30  오후 06:52    <DIR>          ..
# 2026-03-30  오전 11:11    <DIR>          .ipynb_checkpoints
# 2026-03-30  오후 04:23            20,903 numpy실습1.ipynb
# 2026-03-30  오후 04:23            13,018 numpy실습2.ipynb
# 2026-03-30  오후 12:42            12,601 pandas실습1.ipynb
# 2026-04-05  오전 05:46    <DIR>          test1
# 2026-04-05  오전 05:57             7,986 모듈테스트.ipynb
# 2026-04-05  오전 05:49             5,739 입출력테스트.ipynb
#                5개 파일              60,247 바이트
#                4개 디렉터리  23,531,147,264 바이트 남음

# %%
f = open('test1/test1.txt','w')

# %%
print('file test...',file=f)

# %%
f.close()
