# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame(np.random.randn(5,4)) 
df
# Out:
#           0         1         2         3
# 0 -0.570042 -0.714993  0.649850 -1.010631
# 1  0.760107  0.975499  1.347916  1.976495
# 2 -1.278069  0.400469  0.567650 -1.931165
# 3 -0.912314 -0.409440  0.282925  0.829117
# 4 -1.619347  0.251805  1.578621  0.984054

# %%
df.columns = ['A','B','C','D']

# %%
df
# Out:
#           A         B         C         D
# 0 -0.570042 -0.714993  0.649850 -1.010631
# 1  0.760107  0.975499  1.347916  1.976495
# 2 -1.278069  0.400469  0.567650 -1.931165
# 3 -0.912314 -0.409440  0.282925  0.829117
# 4 -1.619347  0.251805  1.578621  0.984054

# %%
df.index = pd.date_range("20200214", periods=5)

# %%
df
# Out:
#                    A         B         C         D
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631
# 2020-02-15  0.760107  0.975499  1.347916  1.976495
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054

# %%
type(df.index)
# Out:
# pandas.DatetimeIndex

# %%
df['E'] = [9.9, np.nan, 10, 9.8, np.nan]

# %%
df
# Out:
#                    A         B         C         D     E
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631   9.9
# 2020-02-15  0.760107  0.975499  1.347916  1.976495   NaN
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054   NaN

# %%
#df.drop?

# %%
#df.dropna?

# %%
df.dropna(how='any')
# Out:
#                    A         B         C         D     E
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631   9.9
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8

# %%
df
# Out:
#                    A         B         C         D     E
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631   9.9
# 2020-02-15  0.760107  0.975499  1.347916  1.976495   NaN
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054   NaN

# %%
df.dropna(how='all')
# Out:
#                    A         B         C         D     E
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631   9.9
# 2020-02-15  0.760107  0.975499  1.347916  1.976495   NaN
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054   NaN

# %%
df.fillna(value=9.7)
# Out:
#                    A         B         C         D     E
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631   9.9
# 2020-02-15  0.760107  0.975499  1.347916  1.976495   9.7
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054   9.7

# %%
df
# Out:
#                    A         B         C         D     E
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631   9.9
# 2020-02-15  0.760107  0.975499  1.347916  1.976495   NaN
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054   NaN

# %%
df.fillna(value=9.7, inplace=True)
# Out:
#                    A         B         C         D     E
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631   9.9
# 2020-02-15  0.760107  0.975499  1.347916  1.976495   9.7
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054   9.7

# %%
df
# Out:
#                    A         B         C         D     E
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631   9.9
# 2020-02-15  0.760107  0.975499  1.347916  1.976495   9.7
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054   9.7

# %%
pd.to_datetime('20200214') # 문자열 형태의 날짜를 날짜 타입(datetime)으로 반환
# Out:
# Timestamp('2020-02-14 00:00:00')

# %%
df.drop(pd.to_datetime('20200214'))
# Out:
#                    A         B         C         D     E
# 2020-02-15  0.760107  0.975499  1.347916  1.976495   9.7
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054   9.7

# %%
df
# Out:
#                    A         B         C         D     E
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631   9.9
# 2020-02-15  0.760107  0.975499  1.347916  1.976495   9.7
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054   9.7

# %%
df.drop([pd.to_datetime('20200214') ,pd.to_datetime('20200216')  ])
# Out:
#                    A         B         C         D    E
# 2020-02-15  0.760107  0.975499  1.347916  1.976495  9.7
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117  9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054  9.7

# %%
df
# Out:
#                    A         B         C         D     E
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631   9.9
# 2020-02-15  0.760107  0.975499  1.347916  1.976495   9.7
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054   9.7

# %%
df.drop('E', axis=1)
# Out:
#                    A         B         C         D
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631
# 2020-02-15  0.760107  0.975499  1.347916  1.976495
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054

# %%
df
# Out:
#                    A         B         C         D     E
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631   9.9
# 2020-02-15  0.760107  0.975499  1.347916  1.976495   9.7
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054   9.7

# %%
df.drop(['B','D'], axis=1)
# Out:
#                    A         C     E
# 2020-02-14 -0.570042  0.649850   9.9
# 2020-02-15  0.760107  1.347916   9.7
# 2020-02-16 -1.278069  0.567650  10.0
# 2020-02-17 -0.912314  0.282925   9.8
# 2020-02-18 -1.619347  1.578621   9.7

# %%
df.drop(df.index[1])

# %%
df.drop(df.index[[1,3]])

# %%
df.drop(df.index[1:3])

# %%
df.drop(df.columns[1:3], axis=1)

# %%
df.drop(df.columns[0], axis=1)

# %%
df
# Out:
#                    A         B         C         D     E
# 2020-02-14 -0.570042 -0.714993  0.649850 -1.010631   9.9
# 2020-02-15  0.760107  0.975499  1.347916  1.976495   9.7
# 2020-02-16 -1.278069  0.400469  0.567650 -1.931165  10.0
# 2020-02-17 -0.912314 -0.409440  0.282925  0.829117   9.8
# 2020-02-18 -1.619347  0.251805  1.578621  0.984054   9.7

# %%
df.drop('E', axis=1, inplace=True)
df
