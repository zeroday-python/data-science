# %%
#%matplotlib nbagg

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
print(matplotlib.__version__)
# Out:
# 3.10.6

# %%
#plt.plot?

# %%
sr = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
sr
# Out:
# 0    -0.815087
# 10    0.064306
# 20   -1.192027
# 30   -0.456846
# 40   -1.054422
# 50   -0.527842
# 60    0.765853
# 70    1.066906
# 80   -0.129828
# 90    1.229438
# dtype: float64

# %%
sr.plot()
plt.savefig('f1.png')

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0  -0.160044  1.569426 -0.951186  0.485932
# 10 -0.885162  2.923213 -2.677203  0.979835
# 20 -2.750310  1.914739 -1.958358  0.133881
# 30 -1.103925  2.363485 -2.689160  0.170279
# 40 -2.008935  2.181061 -2.506515  0.316575
# 50 -0.694797  0.182438 -0.725705  0.036440
# 60 -2.663515 -0.460120 -1.866716  0.051197
# 70 -3.453615 -0.024151 -2.627771 -0.518789
# 80 -4.208618 -0.040703 -4.331981  0.229064
# 90 -4.833900  0.422638 -3.695801  0.243032

# %%
df.plot()
plt.savefig('f2.svg')

# %%
df['D'].plot()
# Out:
# <Axes: >

# %%
sr2 = pd.Series(np.random.rand(15), index=list("abcdefghijklmno"))

# %%
sr2.plot(kind='bar')
# Out:
# <Axes: >

# %%
sr2.plot(kind='barh')
# Out:
# <Axes: >

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Number")) 
df2
# Out:
# Number         A         B         C         D
# one     0.903503  0.454323  0.972964  0.267637
# two     0.669875  0.994547  0.587951  0.097244
# three   0.216148  0.942619  0.014515  0.302439
# four    0.534435  0.272140  0.344208  0.689604
# five    0.151105  0.341438  0.963389  0.708675
# six     0.198491  0.770261  0.361577  0.319825

# %%
df2.plot(kind='bar')
# Out:
# <Axes: >

# %%
df2.plot(kind='barh')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
df2.plot(kind='barh', stacked=True)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sr3 = pd.Series(np.random.normal(0, 1, size=200))
sr3
# Out:
# 0     -1.426535
# 1      0.755069
# 2      0.442875
# 3      1.357126
# 4      1.359664
# 5      1.189272
# 6     -0.764994
# 7     -0.483975
# 8      1.193713
# 9      1.073188
# 10    -1.064653
# 11     0.457049
# 12    -1.472969
# 13    -0.525742
# 14     0.398544
# 15     0.622641
# 16    -0.650668
# 17     0.494390
# 18     0.314583
# 19     0.439608
# 20    -0.546616
# 21     0.173803
# 22    -0.221858
# 23     0.033401
# 24    -0.518141
# 25    -0.429607
# 26    -0.312621
# 27     0.321973
# 28     0.479431
# 29    -0.083749
#          ...
# 170    1.235457
# 171    0.401316
# 172   -1.444888
# 173    0.013473
# 174   -0.787234
# 175   -0.677779
# 176    0.321744
# 177    1.373335
# 178    0.769332
# 179   -1.474519
# 180   -2.042371
# 181    2.273311
# 182   -0.501455
# 183   -0.982513
# 184    0.997445
# 185   -0.258338
# 186   -1.512055
# 187   -0.128256
# 188    1.258580
# 189   -0.039956
# 190    1.367058
# 191   -0.484117
# 192    0.872959
# 193    0.839084
# 194    0.842110
# 195   -0.904486
# 196   -1.322676
# 197   -0.195095
# 198   -0.868135
# 199   -0.791548
# Length: 200, dtype: float64

# %%
sr3.hist()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
x1 = np.random.normal(1, 1, size=(100, 1))
x2 = np.random.normal(-2, 4, size=(100, 1))

# %%
X = np.concatenate((x1, x2), axis=1)

# %%
df3 = pd.DataFrame(X, columns=['x1','x2'])
df3
# Out:
#           x1         x2
# 0   1.368534  -7.499482
# 1   1.011515   0.614398
# 2   2.505769  -0.198733
# 3  -0.566193  -5.072078
# 4   1.608542   3.031264
# 5   3.079160  -5.546996
# 6   0.484701  -5.300564
# 7   0.997152  -2.555046
# 8   0.279323  -1.419196
# 9   0.086123  -6.714146
# 10  1.536289  -2.254779
# 11  0.230413   4.919687
# 12  0.015397  -0.355475
# 13 -0.353733  -4.908216
# 14  1.166207  -6.619917
# 15  0.632368  -1.089045
# 16  2.349069  -3.240758
# 17  1.327506   1.247733
# 18  0.060760  -5.179151
# 19 -0.540503   6.372913
# 20  0.092800  -6.758924
# 21  1.933370   4.401198
# 22  1.488083  -6.615011
# 23  0.396498  -9.517275
# 24  1.067556  -3.266189
# 25  0.574655  -0.042334
# 26  1.064771  -2.860415
# 27 -0.443486  -4.962259
# 28  1.823830  -3.533168
# 29  1.544288   2.475969
# ..       ...        ...
# 70  0.636309   4.835457
# 71  1.360778   2.804477
# 72 -1.174756   3.194447
# 73  0.010569   6.249899
# 74 -0.492101   0.400114
# 75 -1.154182   2.904920
# 76  1.886666  -5.440895
# 77  1.341017   0.476584
# 78  0.863216  -1.682762
# 79  1.683580   4.582527
# 80 -1.860853   0.547110
# 81 -0.292278   1.294219
# 82  0.628488  -6.071009
# 83  1.377065  -0.436505
# 84  0.386732  -0.219425
# 85  1.035605   2.269900
# 86  1.792775  -4.856951
# 87  1.707697   0.214403
# 88  0.848779   0.218824
# 89  0.995983   0.005005
# 90  2.252282   2.342306
# 91  2.210310  -0.487998
# 92  0.701429  -0.775335
# 93  1.751821  -2.319886
# 94  1.769870  -4.940788
# 95  1.978153   1.573394
# 96  1.106645  -5.369639
# 97  1.362153   1.459873
# 98 -0.653595  -5.842030
# 99  0.383403 -13.340257
#
# [100 rows x 2 columns]

# %%
plt.scatter(df3['x1'], df3['x2'])
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
sr = pd.Series(3 * np.random.rand(4), index=['a','b','c','d'], name='series')

# %%
sr.plot.pie(figsize=(6,6))
# Out:
# <img src="data:image/png;base64,..." width="600">

# %%
df = pd.DataFrame(3 * np.random.rand(4,2), index=['a','b','c','d'], columns=['x','y'])
df
# Out:
#           x         y
# a  2.815849  2.320431
# b  0.344837  1.852282
# c  0.059818  1.219851
# d  1.772657  0.042396

# %%
df.plot.pie(subplots=True, figsize=(8,4))
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x00000186576ED320>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x0000018657DAD4A8>],
#       dtype=object)

# %%
df.plot.pie(subplots=True, figsize=(8,4)) 
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="799.9999826604674">
