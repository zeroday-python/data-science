# %%
# %matplotlib nbagg

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
print(pd.__version__)
# Out:
# 2.3.3

# %%
print(matplotlib.__version__)
# Out:
# 3.10.6

# %%
#plt.plot?

# %%
sr = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
sr
# Out:
# 0     1.276374
# 10    3.003994
# 20    3.371269
# 30    2.598946
# 40    3.057591
# 50    1.860971
# 60    0.780514
# 70    1.688007
# 80    1.817430
# 90    0.992913
# dtype: float64

# %%
sr.plot()
plt.savefig('f1.png')

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0  -1.781694 -0.043213  0.537204 -0.605540
# 10 -0.590733  0.377958  1.420710  1.175073
# 20  0.189228 -1.003716  1.595170  2.043932
# 30  0.358664 -1.039405  1.342739  2.316407
# 40  0.641108 -1.154944  0.198251  2.903168
# 50  1.365780 -1.824919 -0.277381  2.948220
# 60  1.025808 -0.550318 -0.249291  4.126986
# 70  0.755550 -1.836886  0.605972  2.931830
# 80  1.058977 -3.094998  0.322643  2.642188
# 90  0.883054 -1.964410 -0.124798  3.251870

# %%
df.plot()
plt.savefig('f2.svg')

# %%
df['D'].plot()
# Out:
# <Axes: >

# %%
sr2 = pd.Series(np.random.rand(15), index=list("abcdefghijklmno"))

# %%
sr2.plot(kind='bar')
# Out:
# <Axes: >

# %%
sr2.plot(kind='barh')
# Out:
# <Axes: >

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Number")) 
df2
# Out:
# Number         A         B         C         D
# one     0.158148  0.291096  0.117334  0.286148
# two     0.079791  0.051329  0.733030  0.489588
# three   0.417148  0.399223  0.883460  0.844902
# four    0.733928  0.404385  0.061467  0.454441
# five    0.096362  0.775838  0.819040  0.278508
# six     0.917413  0.521869  0.238791  0.701408

# %%
df2.plot(kind='bar')
# Out:
# <Axes: >

# %%
df2.plot(kind='barh')
# Out:
# <Axes: >

# %%
df2.plot(kind='barh', stacked=True)
# Out:
# <Axes: >

# %%
sr3 = pd.Series(np.random.normal(0, 1, size=200))
sr3
# Out:
# 0      0.027398
# 1      1.362169
# 2      1.967630
# 3     -1.669338
# 4      1.191181
#          ...
# 195   -1.538069
# 196    0.361115
# 197   -1.882076
# 198   -1.275730
# 199    0.226962
# Length: 200, dtype: float64

# %%
sr3.hist()
# Out:
# <Axes: >

# %%
x1 = np.random.normal(1, 1, size=(100, 1))
x2 = np.random.normal(-2, 4, size=(100, 1))

# %%
X = np.concatenate((x1, x2), axis=1)

# %%
df3 = pd.DataFrame(X, columns=['x1','x2'])
df3
# Out:
#           x1         x2
# 0   2.928158  -1.549319
# 1   0.020845   3.555575
# 2   1.881754  -7.047193
# 3   1.753737 -10.403331
# 4   0.786698  -0.079022
# ..       ...        ...
# 95  0.148766   2.623547
# 96  1.127985  -8.465701
# 97  0.766808  -2.462149
# 98  1.281477  -4.404851
# 99  1.183098   1.319337
#
# [100 rows x 2 columns]

# %%
plt.scatter(df3['x1'], df3['x2'])

# %%
sr = pd.Series(3 * np.random.rand(4), index=['a','b','c','d'], name='series')

# %%
sr.plot.pie(figsize=(6,6))
# Out:
# <Axes: ylabel='series'>

# %%
df = pd.DataFrame(3 * np.random.rand(4,2), index=['a','b','c','d'], columns=['x','y'])
df
# Out:
#           x         y
# a  2.588741  0.846293
# b  0.682042  2.101670
# c  2.714565  1.845650
# d  0.764848  0.432169

# %%
df.plot.pie(subplots=True, figsize=(8,4))
# Out:
# array([<Axes: ylabel='x'>, <Axes: ylabel='y'>], dtype=object)

# %%
df.plot.pie(subplots=True, figsize=(8,4)) 
plt.show()
