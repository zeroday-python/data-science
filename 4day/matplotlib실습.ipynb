# %%
# %matplotlib nbagg

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt

# %%
print(pd.__version__)
# Out:
# 3.0.3

# %%
print(matplotlib.__version__)
# Out:
# 3.10.9

# %%
#plt.plot?

# %%
sr = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))

# %%
sr
# Out:
# 0    -0.357797
# 10   -0.464551
# 20    0.700417
# 30    0.428179
# 40    1.190351
# 50    1.260923
# 60    0.182286
# 70    0.183703
# 80    0.342874
# 90   -0.472047
# dtype: float64

# %%
sr.plot()
plt.savefig('f1.png')

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(axis=0),
                  columns=["A", "B", "C", "D"],
                  index=np.arange(0, 100, 10))
df
# Out:
#            A         B         C         D
# 0   0.750414  0.786354  0.002722 -0.172952
# 10  0.464120 -0.212409 -2.371694 -0.456545
# 20 -0.963125 -0.941885 -2.438210  0.174928
# 30 -1.187134 -0.611112 -2.456768  0.369910
# 40  0.381964 -0.734112 -2.401196  3.377159
# 50 -0.940639 -0.167945 -3.041816  1.964683
# 60 -0.207842  0.786788 -3.388714  0.683159
# 70 -0.449850 -0.018842 -4.128418  2.203114
# 80  0.435105 -0.389399 -4.748001  2.352066
# 90  0.147740 -1.036529 -4.528865  2.690802

# %%
df.plot()
plt.savefig('f2.svg')

# %%
df['D'].plot()
# Out:
# <Axes: >

# %%
sr2 = pd.Series(np.random.rand(15), index=list("abcdefghijklmno"))

# %%
sr2.plot(kind='bar')
# Out:
# <Axes: >

# %%
sr2.plot(kind='barh')
# Out:
# <Axes: >

# %%
df2 = pd.DataFrame(np.random.rand(6, 4), 
                   index=["one", "two", "three", "four", "five", "six"],
                   columns=pd.Index(["A", "B", "C", "D"], name="Number")) 
df2
# Out:
# Number         A         B         C         D
# one     0.872425  0.230856  0.282912  0.543947
# two     0.899922  0.452469  0.194860  0.054261
# three   0.011282  0.187732  0.135379  0.406989
# four    0.126567  0.964532  0.994684  0.784430
# five    0.510004  0.402075  0.471886  0.949277
# six     0.962275  0.933323  0.361034  0.385437

# %%
df2.plot(kind='bar')
# Out:
# <Axes: >

# %%
df2.plot(kind='barh')
# Out:
# <Axes: >

# %%
df2.plot(kind='barh', stacked=True)
# Out:
# <Axes: >

# %%
sr3 = pd.Series(np.random.normal(0, 1, size=200))
sr3
# Out:
# 0     -0.433776
# 1     -0.520345
# 2     -1.257283
# 3     -0.542483
# 4      0.283144
#          ...
# 195   -1.324870
# 196    0.215067
# 197   -0.600555
# 198   -1.288863
# 199   -0.752197
# Length: 200, dtype: float64

# %%
sr3.hist()
# Out:
# <Axes: >

# %%
x1 = np.random.normal(1, 1, size=(100, 1))
x2 = np.random.normal(-2, 4, size=(100, 1))

# %%
X = np.concatenate((x1, x2), axis=1)

# %%
df3 = pd.DataFrame(X, columns=['x1','x2'])
df3
# Out:
#           x1        x2
# 0   2.367182 -0.889652
# 1   0.329367 -5.493622
# 2   1.235454 -3.845401
# 3   1.951479 -5.928517
# 4   2.143982 -3.591968
# ..       ...       ...
# 95  2.315945  2.652974
# 96  2.614426 -3.601299
# 97  0.992341 -6.312027
# 98  1.487192 -5.813552
# 99  2.644193 -0.821943
#
# [100 rows x 2 columns]

# %%
plt.scatter(df3['x1'], df3['x2'])

# %%
sr = pd.Series(3 * np.random.rand(4), index=['a','b','c','d'], name='series')

# %%
sr.plot.pie(figsize=(6,6))
# Out:
# <Axes: >

# %%
df = pd.DataFrame(3 * np.random.rand(4,2), index=['a','b','c','d'], columns=['x','y'])
df
# Out:
#           x         y
# a  0.731434  2.881189
# b  1.619664  1.010667
# c  2.569834  1.126003
# d  0.677895  2.063812

# %%
df.plot.pie(subplots=True, figsize=(8,4))
# Out:
# array([<Axes: >, <Axes: >], dtype=object)

# %%
df.plot.pie(subplots=True, figsize=(8,4)) 
plt.show()
