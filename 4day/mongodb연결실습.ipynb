# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in d:\data-science\.venv\Lib\site-packages (4.17.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in d:\data-science\.venv\Lib\site-packages (from pymongo) (2.8.0)

# %%
import pymongo
from pymongo import MongoClient

# %%
#1.MongoClient 를 연결
client = MongoClient('localhost', 27017)
# client = MongoClient('mongodb://localhost:27017')

# %%
#2. 데이터베이스 연결
# 데이터베이스가 없다면, 새롭게 생성
# 데이터베이스가  있다면, 연결
# sample 이름의 데이터베이스가 생성 됨
db = client.sample

# %%
#3. 컬렉션 연결
# 컬렉션이 없다면, 새롭게 생성
# 컬렉션이 있다면, 연결
# test 이름의 컬렉션이 생성됨
collection = db.test

# %% [markdown]
# ### insert
# - document insert
# - insert() : deprecated
# - insert_one()
# - insert_many()

# %%
print(pymongo.__version__)
# Out:
# 4.17.0

# %%
collection.insert_one({'이름':'이진욱', '직업':'IT개발자'})
# Out:
# InsertOneResult(ObjectId('6a1a9730c1257aed5e0e1563'), acknowledged=True)

# %%
#collection.insert({'이름':'현빈', '직업':'배우'})

# %%
collection.insert_many( [ {'이름':'표선영', '직업':'강사'},
                       {'이름':'현빈', '직업':'IT운영자'},
                       {'이름':'주지훈', '직업':'배우'},
                       {'이름':'김남길', '직업':'IT운영자'},
                       {'이름':'손예진', '직업':'IT개발자'} ] )
# Out:
# InsertManyResult([ObjectId('6a1a9730c1257aed5e0e1564'), ObjectId('6a1a9730c1257aed5e0e1565'), ObjectId('6a1a9730c1257aed5e0e1566'), ObjectId('6a1a9730c1257aed5e0e1567'), ObjectId('6a1a9730c1257aed5e0e1568')], acknowledged=True)

# %% [markdown]
# ### find(select)
# - find()
# - find_one()

# %%
for item in collection.find():
    print(item)
# Out:
# {'_id': ObjectId('6a1a9730c1257aed5e0e1563'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1564'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1565'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1566'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1567'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1568'), '이름': '손예진', '직업': 'IT개발자'}

# %%
collection.find_one({'이름':'표선영'})
# Out:
# {'_id': ObjectId('6a1a9730c1257aed5e0e1564'), '이름': '표선영', '직업': '강사'}

# %%
collection.find_one({'이름':'현빈'})
# Out:
# {'_id': ObjectId('6a1a9730c1257aed5e0e1565'), '이름': '현빈', '직업': 'IT운영자'}

# %%
for item in collection.find().sort('이름'): 
    print(item)
# Out:
# {'_id': ObjectId('6a1a9730c1257aed5e0e1567'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1568'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1563'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1566'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1564'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1565'), '이름': '현빈', '직업': 'IT운영자'}

# %%
for item in collection.find().sort('이름', pymongo.DESCENDING): 
    print(item)
# Out:
# {'_id': ObjectId('6a1a9730c1257aed5e0e1565'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1564'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1566'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1563'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1568'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1567'), '이름': '김남길', '직업': 'IT운영자'}

# %%
for item in collection.find().sort('이름', pymongo.ASCENDING): 
    print(item)
# Out:
# {'_id': ObjectId('6a1a9730c1257aed5e0e1567'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1568'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1563'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1566'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1564'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1565'), '이름': '현빈', '직업': 'IT운영자'}

# %% [markdown]
# ### update
# - update() : deprecated
# - update_one()
# - update_many()

# %%
collection.update_one({'이름':'이진욱'},{ '$set': {'직업':'IT운영자'} })
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
for item in collection.find().sort('이름'): 
    print(item)
# Out:
# {'_id': ObjectId('6a1a9730c1257aed5e0e1567'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1568'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1563'), '이름': '이진욱', '직업': 'IT운영자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1566'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1564'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1565'), '이름': '현빈', '직업': 'IT운영자'}

# %%
collection.update_many({'직업':'배우'},{ '$set': {'직업':'연예인'} })
# Out:
# UpdateResult({'n': 1, 'nModified': 1, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
for item in collection.find().sort('이름'): 
    print(item)
# Out:
# {'_id': ObjectId('6a1a9730c1257aed5e0e1567'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1568'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1563'), '이름': '이진욱', '직업': 'IT운영자'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1566'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1564'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('6a1a9730c1257aed5e0e1565'), '이름': '현빈', '직업': 'IT운영자'}
