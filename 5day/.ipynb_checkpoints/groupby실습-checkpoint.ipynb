# %%
import numpy as np
import pandas as pd

# %%
df = pd.DataFrame({'key1' : ['a', 'a', 'b', 'b', 'a'],
                   'key2' : ['one', 'two', 'one', 'two', 'one'],
                   'data1': np.random.randn(5),
                   'data2': np.random.randn(5)})
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.306687  0.531578
# 1    a  two  2.052250 -0.107398
# 2    b  one  0.946345 -2.551429
# 3    b  two  0.610941 -1.089016
# 4    a  one  0.283944 -0.465889

# %%
grouped = df['data1'].groupby(df['key1'])

# %%
grouped

# %%
grouped.mean()
# Out:
# key1
# a    0.880960
# b    0.778643
# Name: data1, dtype: float64

# %%
#df.groupby?

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.306687  0.531578
# 1    a  two  2.052250 -0.107398
# 2    b  one  0.946345 -2.551429
# 3    b  two  0.610941 -1.089016
# 4    a  one  0.283944 -0.465889

# %%
means = df['data1'].groupby([df['key1'], df['key2']]).mean()
means
# Out:
# key1  key2
# a     one     0.295315
#       two     2.052250
# b     one     0.946345
#       two     0.610941
# Name: data1, dtype: float64

# %%
means.unstack()
# Out:
# key2       one       two
# key1
# a     0.295315  2.052250
# b     0.946345  0.610941

# %%
df
# Out:
#   key1 key2     data1     data2
# 0    a  one  0.306687  0.531578
# 1    a  two  2.052250 -0.107398
# 2    b  one  0.946345 -2.551429
# 3    b  two  0.610941 -1.089016
# 4    a  one  0.283944 -0.465889

# %%
df.groupby('key1').mean(numeric_only=True)
# Out:
#          data1     data2
# key1
# a     0.880960 -0.013903
# b     0.778643 -1.820222

# %%
df['data1'].groupby(df['key1']).mean()
# Out:
# key1
# a    0.880960
# b    0.778643
# Name: data1, dtype: float64

# %%
#df['data1'].groupby('key1').mean() #에러

# %%
df.groupby(['key1','key2']).count()
# Out:
#            data1  data2
# key1 key2
# a    one       2      2
#      two       1      1
# b    one       1      1
#      two       1      1

# %%
for name, group in df.groupby('key1'):
    print(name)
    print(group)
# Out:
# a
#   key1 key2     data1     data2
# 0    a  one  0.306687  0.531578
# 1    a  two  2.052250 -0.107398
# 4    a  one  0.283944 -0.465889
# b
#   key1 key2     data1     data2
# 2    b  one  0.946345 -2.551429
# 3    b  two  0.610941 -1.089016

# %%
print(df.groupby('key1'))
# Out:
# <pandas.core.groupby.generic.DataFrameGroupBy object at 0x0000021E3D7D08A0>

# %%
df2 = pd.DataFrame(np.random.randn(5, 5), 
                   columns=['a', 'b', 'c', 'd', 'e'],
                   index=['Joe', 'Steve', 'Wes', 'Jim', 'Travis'])

# %%
df2
# Out:
#                a         b         c         d         e
# Joe    -0.914070  0.607790  0.049810  0.316262 -0.128769
# Steve   0.240044  0.284724 -0.232138 -1.559819  1.382318
# Wes     1.272149 -0.973115 -2.179415 -0.950429 -0.466860
# Jim     0.239982  0.968871  0.984527  0.920798  0.297364
# Travis -1.234041  0.186424 -1.782859  1.021131 -0.163472

# %%
map_dict = {'a':'red', 'b':'blue', 'c':'red', 'd':'blue', 'e':'red', 'f':'gold'}

# %%
df2.groupby(map_dict, axis=1).sum()
# Out:
# C:\Users\yhkim\AppData\Local\Temp\ipykernel_74192\1465586691.py:1: FutureWarning: DataFrame.groupby with axis=1 is deprecated. Do `frame.T.groupby(...)` without axis instead.
#   df2.groupby(map_dict, axis=1).sum()
#             blue       red
# Joe     0.924052 -0.993030
# Steve  -1.275095  1.390224
# Wes    -1.923544 -1.374127
# Jim     1.889668  1.521872
# Travis  1.207555 -3.180372

# %%
grouped

# %%
grouped.describe()
# Out:
#       count      mean       std       min       25%       50%       75%  \
# key1
# a       3.0  0.880960  1.014431  0.283944  0.295315  0.306687  1.179469
# b       2.0  0.778643  0.237166  0.610941  0.694792  0.778643  0.862494
#
#            max
# key1
# a     2.052250
# b     0.946345
