# %%
import pymongo
from pymongo import MongoClient

# %%
#1.MongoClient 를 연결
client = MongoClient('localhost', 27017)
# client = MongoClient('mongodb://localhost:27017')

# %%
#2. 데이터베이스 연결
# 데이터베이스가 없다면, 새롭게 생성
# 데이터베이스가  있다면, 연결
# sample 이름의 데이터베이스가 생성 됨
db = client.sample

# %%
#3. 컬렉션 연결
# 컬렉션이 없다면, 새롭게 생성
# 컬렉션이 있다면, 연결
# test 이름의 컬렉션이 생성됨
collection = db.test

# %% [markdown]
# ### insert
# - document insert
# - insert() : deprecated
# - insert_one()
# - insert_many()

# %%
print(pymongo.__version__)
# Out:
# 4.16.0

# %%
collection.insert_one({'이름':'이진욱', '직업':'IT개발자'})
# Out:
# InsertOneResult(ObjectId('69c9cee2cdd16be77594ad22'), acknowledged=True)

# %%
#collection.insert({'이름':'현빈', '직업':'배우'})

# %%
collection.insert_many( [ {'이름':'표선영', '직업':'강사'},
                       {'이름':'현빈', '직업':'IT운영자'},
                       {'이름':'주지훈', '직업':'배우'},
                       {'이름':'김남길', '직업':'IT운영자'},
                       {'이름':'손예진', '직업':'IT개발자'} ] )
# Out:
# InsertManyResult([ObjectId('69c9cef4cdd16be77594ad28'), ObjectId('69c9cef4cdd16be77594ad29'), ObjectId('69c9cef4cdd16be77594ad2a'), ObjectId('69c9cef4cdd16be77594ad2b'), ObjectId('69c9cef4cdd16be77594ad2c')], acknowledged=True)

# %% [markdown]
# ### find(select)
# - find()
# - find_one()

# %%
for item in collection.find():
    print(item)
# Out:
# {'_id': ObjectId('69c9caa0b1eab174501df3a3'), '이름': '이진욱', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a4'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9caafb1eab174501df3a5'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a6'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9caafb1eab174501df3a7'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a8'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cbd9b1eab174501df3aa'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ab'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ac'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ad'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ae'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3af'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee2cdd16be77594ad22'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad23'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad24'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad25'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad26'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad27'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad28'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad29'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2a'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2b'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2c'), '이름': '손예진', '직업': 'IT개발자'}

# %%
collection.find_one({'이름':'표선영'})
# Out:
# {'_id': ObjectId('69c9caafb1eab174501df3a4'), '이름': '표선영', '직업': '강사'}

# %%
collection.find_one({'이름':'현빈'})
# Out:
# {'_id': ObjectId('69c9caafb1eab174501df3a5'), '이름': '현빈', '직업': 'IT운영자'}

# %%
for item in collection.find().sort('이름'): 
    print(item)
# Out:
# {'_id': ObjectId('69c9caafb1eab174501df3a7'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ae'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad26'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2b'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a8'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3af'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad27'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2c'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caa0b1eab174501df3a3'), '이름': '이진욱', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbd9b1eab174501df3aa'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee2cdd16be77594ad22'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a6'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ad'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad25'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2a'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('69c9caafb1eab174501df3a4'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ab'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad23'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad28'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9caafb1eab174501df3a5'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ac'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad24'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad29'), '이름': '현빈', '직업': 'IT운영자'}

# %%
for item in collection.find().sort('이름', pymongo.DESCENDING): 
    print(item)
# Out:
# {'_id': ObjectId('69c9caafb1eab174501df3a5'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ac'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad24'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad29'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a4'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ab'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad23'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad28'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9caafb1eab174501df3a6'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ad'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad25'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2a'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('69c9caa0b1eab174501df3a3'), '이름': '이진욱', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbd9b1eab174501df3aa'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee2cdd16be77594ad22'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a8'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3af'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad27'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2c'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a7'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ae'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad26'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2b'), '이름': '김남길', '직업': 'IT운영자'}

# %%
for item in collection.find().sort('이름', pymongo.ASCENDING): 
    print(item)
# Out:
# {'_id': ObjectId('69c9caafb1eab174501df3a7'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ae'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad26'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2b'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a8'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3af'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad27'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2c'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caa0b1eab174501df3a3'), '이름': '이진욱', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbd9b1eab174501df3aa'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee2cdd16be77594ad22'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a6'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ad'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad25'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2a'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('69c9caafb1eab174501df3a4'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ab'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad23'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad28'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9caafb1eab174501df3a5'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ac'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad24'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad29'), '이름': '현빈', '직업': 'IT운영자'}

# %% [markdown]
# ### update
# - update() : deprecated
# - update_one()
# - update_many()

# %%
collection.update_one({'이름':'이진욱'},{ '$set': {'직업':'IT운영자'} })
# Out:
# UpdateResult({'n': 1, 'nModified': 0, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
for item in collection.find().sort('이름'): 
    print(item)
# Out:
# {'_id': ObjectId('69c9caafb1eab174501df3a7'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ae'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad26'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2b'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a8'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3af'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad27'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2c'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caa0b1eab174501df3a3'), '이름': '이진욱', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbd9b1eab174501df3aa'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee2cdd16be77594ad22'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a6'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ad'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad25'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2a'), '이름': '주지훈', '직업': '배우'}
# {'_id': ObjectId('69c9caafb1eab174501df3a4'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ab'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad23'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad28'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9caafb1eab174501df3a5'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ac'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad24'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad29'), '이름': '현빈', '직업': 'IT운영자'}

# %%
collection.update_many({'직업':'배우'},{ '$set': {'직업':'연예인'} })
# Out:
# UpdateResult({'n': 2, 'nModified': 2, 'ok': 1.0, 'updatedExisting': True}, acknowledged=True)

# %%
for item in collection.find().sort('이름'): 
    print(item)
# Out:
# {'_id': ObjectId('69c9caafb1eab174501df3a7'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ae'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad26'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2b'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a8'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3af'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad27'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2c'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caa0b1eab174501df3a3'), '이름': '이진욱', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbd9b1eab174501df3aa'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee2cdd16be77594ad22'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a6'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ad'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad25'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2a'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9caafb1eab174501df3a4'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ab'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad23'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad28'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9caafb1eab174501df3a5'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ac'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad24'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad29'), '이름': '현빈', '직업': 'IT운영자'}

# %% [markdown]
# ### delete
# - remove() :deprecated
# - delete_one()
# - delete_many()

# %%
for item in collection.find().sort('이름'): 
    print(item)
# Out:
# {'_id': ObjectId('69c9caafb1eab174501df3a7'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ae'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad26'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2b'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a8'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3af'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad27'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2c'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caa0b1eab174501df3a3'), '이름': '이진욱', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbd9b1eab174501df3aa'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee2cdd16be77594ad22'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a6'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ad'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad25'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2a'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9caafb1eab174501df3a4'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ab'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad23'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad28'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9caafb1eab174501df3a5'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ac'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad24'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad29'), '이름': '현빈', '직업': 'IT운영자'}

# %%
collection.delete_one({'이름':'이진욱'})
# Out:
# DeleteResult({'n': 1, 'ok': 1.0}, acknowledged=True)

# %%
for item in collection.find().sort('이름'): 
    print(item)
# Out:
# {'_id': ObjectId('69c9caafb1eab174501df3a7'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ae'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad26'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2b'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a8'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3af'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad27'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2c'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cbd9b1eab174501df3aa'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee2cdd16be77594ad22'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a6'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ad'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad25'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2a'), '이름': '주지훈', '직업': '연예인'}
# {'_id': ObjectId('69c9caafb1eab174501df3a4'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ab'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad23'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad28'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9caafb1eab174501df3a5'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ac'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad24'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad29'), '이름': '현빈', '직업': 'IT운영자'}

# %%
collection.delete_many({'이름':'주지훈'})
# Out:
# DeleteResult({'n': 4, 'ok': 1.0}, acknowledged=True)

# %%
for item in collection.find().sort('이름'): 
    print(item)
# Out:
# {'_id': ObjectId('69c9caafb1eab174501df3a7'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ae'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad26'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2b'), '이름': '김남길', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a8'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3af'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad27'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad2c'), '이름': '손예진', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cbd9b1eab174501df3aa'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9cee2cdd16be77594ad22'), '이름': '이진욱', '직업': 'IT개발자'}
# {'_id': ObjectId('69c9caafb1eab174501df3a4'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ab'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad23'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad28'), '이름': '표선영', '직업': '강사'}
# {'_id': ObjectId('69c9caafb1eab174501df3a5'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cbdbb1eab174501df3ac'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cee4cdd16be77594ad24'), '이름': '현빈', '직업': 'IT운영자'}
# {'_id': ObjectId('69c9cef4cdd16be77594ad29'), '이름': '현빈', '직업': 'IT운영자'}

# %% [markdown]
# - 기타 함수

# %%
collection.estimated_document_count()
# Out:
# 18

# %%
# pymongo 3.7 이상에서 추가
collection.count_documents( { } )
# Out:
# 18

# %%
print(pymongo.__version__)
# Out:
# 4.16.0

# %%
collection.count_documents( {'이름':'현빈' } )
# Out:
# 4

# %%
#db.collection_names()

# %%
db.list_collection_names()
# Out:
# ['test']

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'jsondb', 'local', 'sample']

# %%
client.list_database_names()
# Out:
# ['admin', 'config', 'jsondb', 'local', 'sample']

# %%
db.drop_collection(collection)
# Out:
# {'nIndexesWas': 1, 'ns': 'sample.test', 'ok': 1.0}

# %%
client.drop_database(db)
